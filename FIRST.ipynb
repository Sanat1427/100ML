# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanat1427/100ML/blob/main/FIRST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 96   4.4   42.0
# 47   5.2  161.0
# 83   7.5  130.0
# 20   6.6  120.0
# 54   6.4  141.0
# ..   ...    ...
# 2    5.3  121.0
# 67   5.0  118.0
# 66   6.9   96.0
# 88   4.4  149.0
# 71   6.1  132.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 96    0
# 47    0
# 83    1
# 20    1
# 54    1
#      ..
# 2     0
# 67    0
# 66    1
# 88    0
# 71    1
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 90   7.3   86.0
# 74   6.7  154.0
# 57   6.5  130.0
# 62   6.0  102.0
# 45   6.0   66.0
# 51   4.8  141.0
# 60   6.9  139.0
# 79   6.5   90.0
# 80   4.9  196.0
# 41   5.4  114.0

# %%
y_test
# Out:
# 90    1
# 74    1
# 57    1
# 62    0
# 45    1
# 51    0
# 60    1
# 79    1
# 80    0
# 41    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sclaer=StandardScaler()

# %%
X_train=sclaer.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.35085506, -2.03886252],
#        [-0.66639648,  0.92801487],
#        [ 1.30142194,  0.15513084],
#        [ 0.53140604, -0.09418658],
#        [ 0.36029139,  0.42938001],
#        [-0.92306844, -1.56515941],
#        [ 0.70252068, -0.84213887],
#        [-0.7519538 ,  0.10526736],
#        [ 1.98588052,  1.10253707],
#        [-1.09418309, -0.06925484],
#        [-1.00862577, -0.29364053],
#        [ 2.15699516, -0.09418658],
#        [ 0.0180621 , -1.96406729],
#        [ 1.30142194,  0.85321964],
#        [-0.15305254,  0.45431176],
#        [ 1.13030729,  0.32965304],
#        [ 0.61696336,  1.45158147],
#        [ 1.30142194, -1.56515941],
#        [-0.66639648, -0.84213887],
#        [ 0.87363533,  1.87542109],
#        [-1.77864167, -0.36843575],
#        [-0.66639648,  2.49871466],
#        [ 0.87363533, -1.49036418],
#        [ 0.87363533,  0.37951653],
#        [ 0.95919265, -1.88927206],
#        [-0.7519538 , -1.44050069],
#        [ 1.72920855, -1.11638804],
# ...

# %%
X_test=sclaer.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.13030729, -0.94186584],
#        [ 0.61696336,  0.75349267],
#        [ 0.44584871,  0.15513084],
#        [ 0.0180621 , -0.54295795],
#        [ 0.0180621 , -1.44050069],
#        [-1.00862577,  0.42938001],
#        [ 0.788078  ,  0.37951653],
#        [ 0.44584871, -0.84213887],
#        [-0.92306844,  1.80062587],
#        [-0.49528183, -0.24377704]])

# %%
 from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
#model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred =clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >
